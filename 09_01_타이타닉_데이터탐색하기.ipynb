# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df_titanic = pd.read_csv("https://raw.githubusercontent.com/datascienceschool/docker_rpython/master/data/titanic.csv")
df_titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_titanic.shape  # row, column 순
# Out:
# (891, 12)

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_titanic.describe()  # 기초통계(개수, 평균, 표준편차,최솟값, 25분위수, 중앙값, 75분위수, 최대값)
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_titanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df_titanic.describe(include='O')
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %% [markdown]
# 생존율과 객실등급 간의 상관관계를 분석해보세요.

# %%
list(df_titanic)   # 데이터프레임 list 로 형변환하면 column 값들이 나옴.
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
col = list(df_titanic)
col.pop(0)
# Out:
# 'PassengerId'

# %%
col  # pop 함수로 Passengerld 없어짐.
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
col.insert(0, col.pop())

# %%
col
# Out:
# ['Embarked',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin']

# %%
col[:3]
# Out:
# ['Embarked', 'Survived', 'Pclass']

# %%
df_titanic[col[:3]]  # => df_titanic[ ['Embarked', 'Survived', 'Pclass'] ]
# Out:
#     Embarked  Survived  Pclass
# 0          S         0       3
# 1          C         1       1
# 2          S         1       3
# 3          S         1       1
# 4          S         0       3
# ..       ...       ...     ...
# 886        S         0       2
# 887        S         1       1
# 888        S         0       3
# 889        C         1       1
# 890        Q         0       3
#
# [891 rows x 3 columns]

# %%
df_titanic[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 생존율과 다음 컬럼값들 간의 상관관계를 분석해보세요.
# ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# 상관관계 > Table로 표현해보세요.

# %%
corr = df_titanic[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Survived']].corr()

# %%
corr   # Pclass 와 Fare 관계 => Fare(요금)이 높아질수록 Pclass(방등급) 숫자가 낮은게 좋은 방임.
# Out:
#             Pclass       Age     SibSp     Parch      Fare  Survived
# Pclass    1.000000 -0.369226  0.083081  0.018443 -0.549500 -0.338481
# Age      -0.369226  1.000000 -0.308247 -0.189119  0.096067 -0.077221
# SibSp     0.083081 -0.308247  1.000000  0.414838  0.159651 -0.035322
# Parch     0.018443 -0.189119  0.414838  1.000000  0.216225  0.081629
# Fare     -0.549500  0.096067  0.159651  0.216225  1.000000  0.257307
# Survived -0.338481 -0.077221 -0.035322  0.081629  0.257307  1.000000

# %%
df_titanic[['Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Survived']].corr()[['Survived']]
# Out:
#           Survived
# Pclass   -0.338481
# Age      -0.077221
# SibSp    -0.035322
# Parch     0.081629
# Fare      0.257307
# Survived  1.000000

# %% [markdown]
# 상관관계 > heatmap으로 표현해보세요.
#
# seaborn의 heatmap 활용
#
# - cmap: 'coolwarm' # 컬러 구성
# - annot: True # 각 셀의 값 표기
# - fmt: '.2f' # 숫자표현포맷

# %%
sns.heatmap(corr, cmap='coolwarm', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# 각각을 bar plot으로 시각화해보세요.
#
# 검은색 bar는 오차막대(error bar) 이며 신뢰구간(confidence interval) 95%
#
# catplot활용
# - x: x축 column명
# - y: y축 column명
# - data: dataframe
# - kind: 'bar'

# %%
g = sns.catplot(x='Pclass', y='Survived', data=df_titanic, kind='bar')

# %%
g = sns.catplot(x='SibSp', y='Survived', data=df_titanic, kind='bar')

# %%
g = sns.catplot(x='Parch', y='Survived', data=df_titanic, kind='bar')

# %% [markdown]
# 생존자와 사망자 간의 각 나이 분포도를 히스토그램으로 시각화해보세요.
#
# - 데이터프레임 groupby
# - hist 메서드 활용, bins

# %%
# df_titanic[['Age', 'Survived']].groupby(['Survived']).hist(bins=20)
df_titanic[df_titanic['Survived'] == 1]['Age'].hist(bins=20)
plt.show()
df_titanic[df_titanic['Survived'] == 0]['Age'].hist(bins=20)
plt.show()

# %%
# sns subplot 그리기 (col 기준) (row 기준)
g = sns.FacetGrid(df_titanic, col='Survived')
g = g.map(sns.histplot, 'Age', kde=True) # kde=True, kernel density estimate to smooth the distribution and show on the plot as (one or more) line(s)

# %%
# kde plot
g = sns.kdeplot(df_titanic["Age"][(df_titanic["Survived"] == 0) & (df_titanic["Age"].notnull())], color="Red", fill= True)
g = sns.kdeplot(df_titanic["Age"][(df_titanic["Survived"] == 1) & (df_titanic["Age"].notnull())], ax =g, color="Blue", fill= True)
g.set_xlabel("Age")
g.set_ylabel("Frequency")
g = g.legend(["Not Survived", "Survived"])

# %% [markdown]
# 성별에 따른 생존율을 비교해보세요.
#
# 남자 : 생존율
# 여자 : 생존율

# %%
df_titanic.groupby('Sex').mean()[['Survived']]
# Out:
# <ipython-input-46-d86b1f94bcea>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_titanic.groupby('Sex').mean()[['Survived']]
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
sns.catplot(x='Sex', y='Survived', data=df_titanic, kind='bar')

# %% [markdown]
# 객실등급에 따른 생존율을 비교해보세요.
#
# 1등급 : 생존율
# 2등급 : 생존율
# 3등급 : 생존율

# %%
df_titanic.groupby('Pclass').mean()[['Survived']]
# Out:
# <ipython-input-48-8ebfea35c848>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_titanic.groupby('Pclass').mean()[['Survived']]
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
sns.catplot(x='Pclass', y='Survived', data=df_titanic, kind='bar')

# %% [markdown]
# 하나의 그래프에 객실등급과 성별에 대한 생존율을 함께 시각화해보세요.

# %%
df_titanic.groupby(['Sex', 'Pclass']).mean()[['Survived']]
# Out:
# <ipython-input-51-ff90e7be0186>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_titanic.groupby(['Sex', 'Pclass']).mean()[['Survived']]
#                Survived
# Sex    Pclass
# female 1       0.968085
#        2       0.921053
#        3       0.500000
# male   1       0.368852
#        2       0.157407
#        3       0.135447

# %%
g = sns.catplot(x='Pclass', y='Survived', hue='Sex', data=df_titanic, kind='bar')

# %% [markdown]
# 성별에 따른 나이의 분포를 분석해보세요.
#
# 객실등급에 따른 나이의 분포를 분석해보세요.

# %%
sns.catplot(x='Sex', y='Age', data=df_titanic, kind='box')
sns.catplot(x='Sex', y='Age', data=df_titanic, kind='violin')
sns.catplot(x='Pclass', y='Age', data=df_titanic, kind='strip')
sns.catplot(x='Pclass', y='Age', data=df_titanic, kind='swarm')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 18.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# 항구에 따른 생존율을 시각화해보세요.
#
# catplot 활용
# - data: dataframe
# - kind: bar

# %%
g = sns.catplot(x='Embarked', y='Survived', data=df_titanic, kind='bar')

# %% [markdown]
# 항구에 따라 생존율의 차이가 있습니다.
# 왜일까?
# 항구에 따라 탑승하는 객실등급 수준의 차이가 있는건 아닐까.. Hoxi..?
#
# 객실등급과 항구간의 관계를 확인해보세요

# %%
count_em_pc = df_titanic[['Pclass', 'Embarked', 'PassengerId']].groupby(['Embarked', 'Pclass']).count()
count_em_pc
# Out:
#                  PassengerId
# Embarked Pclass
# C        1                85
#          2                17
#          3                66
# Q        1                 2
#          2                 3
#          3                72
# S        1               127
#          2               164
#          3               353

# %% [markdown]
#   count plot을 이용해서 표현해보자.

# %%
sns.catplot(x="Pclass", col="Embarked",  data=df_titanic,
                   kind="count", palette="muted")

# %% [markdown]
# 항구와 객실등급에 따른 생존율

# %%
g = sns.catplot(x='Embarked', y='Survived', data=df_titanic, kind='bar',
                   aspect=1)

# %%
g = sns.catplot(x='Embarked', y='Survived', hue='Pclass', data=df_titanic, kind='bar',
                   aspect=3)

# %% [markdown]
# 요금의 분포를 시각화해보세요.

# %%
plt.hist(df_titanic["Fare"], bins=100)
plt.show()

# %%
g = sns.kdeplot(df_titanic["Fare"])

# %%
df_titanic["Fare"].skew()
# Out:
# 4.787316519674893

# %% [markdown]
# skewness는 -2 이하, 2 이상이 기준

# %% [markdown]
# 치우침(Skewness)가 가장 심한 feature가 무엇인지 찾아보세요.
#
# df의 skew() method 활용
#
# 0. skew를 활용해 데이터를 추출하고
# 1. 데이터프레임을 생성
# 2. index로 들어가있는 데이터로 feature 칼럼을 생성
# 3. barplot 생성

# %%
skew = df_titanic.skew()
# Out:
# <ipython-input-62-8091fc360781>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skew = df_titanic.skew()

# %%
df_skew = pd.DataFrame(skew,
                       columns=['skew'])
df_skew
# Out:
#                  skew
# PassengerId  0.000000
# Survived     0.478523
# Pclass      -0.630548
# Age          0.389108
# SibSp        3.695352
# Parch        2.749117
# Fare         4.787317

# %%
df_skew['feature'] = df_skew.index
df_skew
# Out:
#                  skew      feature
# PassengerId  0.000000  PassengerId
# Survived     0.478523     Survived
# Pclass      -0.630548       Pclass
# Age          0.389108          Age
# SibSp        3.695352        SibSp
# Parch        2.749117        Parch
# Fare         4.787317         Fare

# %%
sns.catplot(x='feature', y='skew', data=df_skew, kind='bar')

# %% [markdown]
# 첨도(Kurtosis)가 가장 심한 feature가 무엇인지 찾아보세요.
#
# 데이터프레임의 kurt() method 활용

# %%
df_titanic.kurt().sort_values(ascending=False)
# Out:
# <ipython-input-66-93a5d6898088>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_titanic.kurt().sort_values(ascending=False)
# Fare           33.398141
# SibSp          17.880420
# Parch           9.778125
# Age             0.178274
# PassengerId    -1.200000
# Pclass         -1.280015
# Survived       -1.775005
# dtype: float64

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic[['Name', 'Ticket', 'Cabin']].describe()
# Out:
#                            Name  Ticket    Cabin
# count                       891     891      204
# unique                      891     681      147
# top     Braund, Mr. Owen Harris  347082  B96 B98
# freq                          1       7        4

# %% [markdown]
# Name, Ticket, Cabin은 모두 unique값이 많기 때문에, 데이터 자체값으로는 큰의미가 없다. 데이터를 직접 살펴보고, 유의미한 value를 추출할 수 있을지 고민해야한다.

# %%
df_titanic['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df_titanic.Name
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# 전체 이름에서, . 앞에 있는 알파벳묶음열(알파벳으로만 이루어진 문자열)을 찾아내고 싶다면?

# %%
# .
# ?
# +
# *
# []
# [^]
# ()

# 회피용법 \. \? \+ \* \[ \] \^ \( \)

# greedy Q : 최대한 긴 문자열로 찾아낸다. = .+
# reluctant Q : 최대한 짧은 문자열로 찾아낸다. = .+?

# %%
df_titanic['Title'] = df_titanic.Name.str.extract('([A-Za-z]+)\.', expand=True) # 정규표현식 7가지 핵심 문법 ? . + * [] [^] ()

# %%
import re
text = 'abc.def..ght..xyz.poi'
rq = re.findall('\.(.+?)\.', text)
gq = re.findall('\.(.+)\.', text)
rq, gq
# Out:
# (['def', 'ght', 'xyz'], ['def..ght..xyz'])

# %%
df_titanic['Title'] = df_titanic.Name.str.extract(',\s(.+?)\.', expand=True) # .+? = 문자열

# %%
df_titanic['Title']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object

# %%
pd.crosstab(df_titanic['Title'], df_titanic['Sex'])
# Out:
# Sex           female  male
# Title
# Capt               0     1
# Col                0     2
# Don                0     1
# Dr                 1     6
# Jonkheer           0     1
# Lady               1     0
# Major              0     2
# Master             0    40
# Miss             182     0
# Mlle               2     0
# Mme                1     0
# Mr                 0   517
# Mrs              125     0
# Ms                 1     0
# Rev                0     6
# Sir                0     1
# the Countess       1     0

# %%
list(df_titanic)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Title']

# %%
pd.crosstab(df_titanic['Title'], df_titanic['Pclass'])
# Out:
# Pclass          1   2    3
# Title
# Capt            1   0    0
# Col             2   0    0
# Don             1   0    0
# Dr              5   2    0
# Jonkheer        1   0    0
# Lady            1   0    0
# Major           2   0    0
# Master          3   9   28
# Miss           46  34  102
# Mlle            2   0    0
# Mme             1   0    0
# Mr            107  91  319
# Mrs            42  41   42
# Ms              0   1    0
# Rev             0   6    0
# Sir             1   0    0
# the Countess    1   0    0

# %%
pd.crosstab(df_titanic['Title'], df_titanic['Survived'])
# Out:
# Survived        0    1
# Title
# Capt            1    0
# Col             1    1
# Don             1    0
# Dr              4    3
# Jonkheer        1    0
# Lady            0    1
# Major           1    1
# Master         17   23
# Miss           55  127
# Mlle            0    2
# Mme             0    1
# Mr            436   81
# Mrs            26   99
# Ms              0    1
# Rev             6    0
# Sir             0    1
# the Countess    0    1

# %%
df_titanic['Name'].str.split(',')
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %% [markdown]
# 이름에서 Mr, Miss 등 성별 혹은 직위를 나타내는 칭호가 있다. 이것은 생존율에 쓸만하지 않을까?
#
#   이녀석만 따로 빼내자.

# %%
[i.split(",")[1] for i in df_titanic["Name"]]
# Out:
# [' Mr. Owen Harris',
#  ' Mrs. John Bradley (Florence Briggs Thayer)',
#  ' Miss. Laina',
#  ' Mrs. Jacques Heath (Lily May Peel)',
#  ' Mr. William Henry',
#  ' Mr. James',
#  ' Mr. Timothy J',
#  ' Master. Gosta Leonard',
#  ' Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#  ' Mrs. Nicholas (Adele Achem)',
#  ' Miss. Marguerite Rut',
#  ' Miss. Elizabeth',
#  ' Mr. William Henry',
#  ' Mr. Anders Johan',
#  ' Miss. Hulda Amanda Adolfina',
#  ' Mrs. (Mary D Kingcome) ',
#  ' Master. Eugene',
#  ' Mr. Charles Eugene',
#  ' Mrs. Julius (Emelia Maria Vandemoortele)',
#  ' Mrs. Fatima',
#  ' Mr. Joseph J',
#  ' Mr. Lawrence',
#  ' Miss. Anna "Annie"',
#  ' Mr. William Thompson',
#  ' Miss. Torborg Danira',
#  ' Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  ' Mr. Farred Chehab',
#  ' Mr. Charles Alexander',
#  ' Miss. Ellen "Nellie"',
#  ' Mr. Lalio',
#  ' Don. Manuel E',
#  ' Mrs. William Augustus (Marie Eugenie)',
#  ' Miss. Mary Agatha',
#  ' Mr. Edward H',
#  ' Mr. Edgar Joseph',
#  ' Mr. Alexander Oskar',
#  ' Mr. Hanna',
#  ' Mr. Ernest Charles',
#  ' Miss. Augusta Maria',
#  ' Miss. Jamila',
#  ' Mrs. Johan (Johanna Persdotter Larsson)',
#  ' Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  ' Mr. Theodor',
#  ' Miss. Simonne Marie Anne Andree',
#  ' Miss. Margaret Delia',
#  ' Mr. William John',
#  ' Mr. Denis',
#  ' Miss. Bridget',
#  ' Mr. Youssef',
#  ' Mrs. Josef (Josefine Franchi)',
#  ' Master. Juha Niilo',
#  ' Mr. Richard Cater',
#  ' Mrs. Henry Sleeper (Myna Haxtun)',
#  ' Mrs. Lizzie (Elizabeth Anne Wilkinson)',
#  ' Mr. Engelhart Cornelius',
#  ' Mr. Hugh',
#  ' Miss. Emily',
#  ' Mr. Mansouer',
#  ' Miss. Constance Mirium',
#  ' Master. William Frederick',
#  ' Mr. Orsen',
#  ' Miss. Amelie',
#  ' Mr. Henry Birkhardt',
#  ' Master. Harald',
#  ' Mr. Albert A',
#  ' Master. Gerios',
#  ' Mrs. (Elizabeth Ramell)',
#  ' Mr. Ernest James',
#  ' Miss. Erna Alexandra',
#  ' Mr. Vincenz',
#  ' Mr. Stephen Curnow',
#  ' Miss. Lillian Amy',
#  ' Mr. Ambrose Jr',
#  ' Mr. Apostolos',
#  ' Mr. Lee',
#  ' Mr. Sigurd Hansen',
#  ' Mr. Ivan',
#  ' Mr. Rahamin Haim',
#  ' Master. Alden Gates',
#  ' Miss. Elizabeth',
#  ' Mr. Achille',
#  ' Mr. Jan Baptist',
#  ' Miss. Brigdet Delia',
#  ' Mr. Francisco M',
#  ' Miss. Bertha',
#  ' Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  ' Mr. William Neal',
#  ' Mr. Selman Francis',
#  ' Miss. Mabel Helen',
#  ' Mr. Francesco',
#  ' Mr. Emil',
#  ' Mr. Paul Edvin',
#  ' Mr. Herbert Fuller',
#  ' Mr. Bertram Frank',
#  ' Mr. Daniel',
#  ' Mr. Charles Joseph',
#  ' Mr. George B',
#  ' Mr. William Bertram',
#  ' Mrs. John T (Ada Julia Bone)',
#  ' Mr. Sinai',
#  ' Miss. Matilda',
#  ' Mr. Pastcho ("Pentcho")',
#  ' Mr. Richard Frasar',
#  ' Mr. Gustaf Joel',
#  ' Mr. Anders Vilhelm',
#  ' Mr. Stoytcho',
#  ' Miss. Anna Kristine',
#  ' Mr. Albert Johan',
#  ' Mr. Tido',
#  ' Miss. Bertha',
#  ' Mr. Walter Chamberlain',
#  ' Miss. Hileni',
#  ' Mr. David John',
#  ' Miss. Katriina',
#  ' Miss. Malake',
#  ' Mr. Edvard',
#  ' Mr. Patrick',
#  ' Mr. William John Robert',
#  ' Mr. Quigg Edmond',
#  ' Miss. Ellis Anna Maria',
#  ' Mr. Stanley George',
#  ' Mr. Leonard Charles',
#  ' Mr. Nicholas',
#  ' Miss. Susan',
#  ' Mr. Percival Wayland',
#  ' Master. Elias',
#  ' Mr. Martin',
#  ' Mr. Fridtjof Arne',
#  ' Miss. Anna',
#  ' Mr. Johan',
#  ' Mr. Jozef',
#  ' Mr. Domingos Fernandeo',
#  ' Mrs. Alexander A (Grace Charity Laury)',
#  ' Mrs. Leopold (Mathilde Francoise Pede)',
#  ' Mr. Samuel James Hayden',
#  ' Mr. Emile',
#  ' Miss. Helen Monypeny',
#  ' Mr. Jacques Heath',
#  ' Mr. Olaf Elon',
#  ' Mr. Victor',
#  ' Mrs. Joseph (Sultana)',
#  ' Miss. Anna Sofia',
#  ' Mrs. Pekka Pietari (Elin Matilda Dolck)',
#  ' Mr. Jeremiah',
#  ' Mr. Edgardo Samuel',
#  ' Mr. Joseph Charles',
#  ' Mr. August Edvard ("Wennerstrom")',
#  ' Miss. Robina Maggie "Ruby"',
#  ' Mr. Michel ("Louis M Hoffman")',
#  ' Rev. Thomas Roussel Davids',
#  ' Rev. Robert James',
#  ' Mrs. Thomas (Edith Wearne)',
#  ' Mr. Alfonzo',
#  ' Mr. Austin Blyler',
#  ' Mr. Ole Martin',
#  ' Mr. Charles Duane',
#  ' Miss. Katherine "Katie"',
#  ' Mr. Harry',
#  ' Mr. Mile',
#  ' Master. Thomas Henry',
#  ' Mr. John Hatfield',
#  ' Mrs. James (Elizabeth "Bessie" Inglis Milne)',
#  ' Mr. John Viktor',
#  ' Mr. Jovo',
#  ' Master. Eino Viljami',
#  ' Master. Frank John William "Frankie"',
#  ' Mrs. (Edith Martha Bowerman)',
#  ' Mrs. William (Anna Bernhardina Karlsson)',
#  ' Mr. John D',
#  ' Mr. Lee',
#  ' Mr. Wyckoff',
#  ' Master. Arthur',
#  ' Miss. Eleanor Ileen',
#  ' Mr. Antti Wilhelm',
#  ' Mr. James Clinch',
#  ' Mr. Klas Albin',
#  ' Master. Henry Forbes',
#  ' Miss. Ann Elizabeth',
#  ' Mr. Reginald',
#  ' Mr. Lionel',
#  ' Miss. Constance Gladys',
#  ' Mr. Rene',
#  ' Master. Clarence Gustaf Hugo',
#  ' Master. Richard F',
#  ' Miss. Luise Gretchen',
#  ' Mr. Hugh Roscoe',
#  ' Mrs. Thomas (Johanna "Hannah" Godfrey)',
#  ' Mr. Charles Hallace ("Mr C Rolmane")',
#  ' Mr. John',
#  ' Mr. Stjepan',
#  ' Mrs. (Rosa)',
#  ' Mr. William',
#  ' Miss. Carla Christine Nielsine',
#  ' Master. Michel M',
#  ' Mrs. James Joseph (Margaret Tobin)',
#  ' Miss. Elise',
#  ' Mr. Robert',
#  ' Mr. Karl Siegwart Andreas',
#  ' Miss. Margaret "Maggie"',
#  ' Miss. Henriette ("Mrs Harbeck")',
#  ' Mr. Nestor Cyriel',
#  ' Mr. Frederick',
#  ' Mr. Jakob Alfred',
#  ' Mr. Gerious',
#  ' Mr. Gurshon "Gus"',
#  ' Miss. Telma Matilda',
#  ' Mr. Karl Alfred',
#  ' Mr. Nassef Cassem',
#  ' Miss. Helen "Ellen"',
#  ' Mr. Henry',
#  ' Mr. Ahmed',
#  ' Miss. Clear Annie',
#  ' Mr. John Henry',
#  ' Mr. Hans Kristensen',
#  ' Mr. Philip',
#  ' Miss. Madeleine',
#  ' Miss. Eliina',
#  ' Mr. Sidney Samuel',
#  ' Miss. Albina',
#  ' Mr. Walter',
#  ' Mr. Victor Francis',
#  ' Mr. James H',
#  ' Mr. George Henry',
#  ' Mr. Christo',
#  ' Mr. Frederick Maxfield',
#  ' Mr. Karl Ivar Sven',
#  ' Mr. William John',
#  ' Mr. John Hall ("Henry")',
#  ' Mr. Arne Jonas',
#  ' Miss. Mathilde',
#  ' Mrs. Henry Birkhardt (Irene Wallach)',
#  ' Mr. Bengt Edvin',
#  ' Mr. Ernst Adolf',
#  ' Miss. Lillian Gertrud',
#  ' Mr. Robert William Norman',
#  ' Miss. Alice Phoebe',
#  ' Mr. Stephen',
#  ' Miss. Marjorie "Lottie"',
#  ' Mr. Frederick William',
#  ' Mr. George Henry',
#  ' Miss. Thamine',
#  ' Miss. Katherine "Kate"',
#  ' Mr. Reginald Charles',
#  ' Mr. Matti Alexanteri',
#  ' Mr. Sleiman',
#  ' Dr. William Edward',
#  ' Miss. Agda Thorilda Viktoria',
#  ' Mrs. William (Anna)',
#  ' Mr. Richard Leonard',
#  ' Rev. Ernest Courtenay',
#  ' Mr. James George',
#  ' Mrs. Wilhelm (Elna Matilda Persson)',
#  ' Mr. William Thomas',
#  ' Mr. William Arthur',
#  ' Mrs. Viktor (Helena Wilhelmina)',
#  ' Mrs. Darwis (Hanne Youssef Razi)',
#  ' Mrs. Gertrude Maybelle',
#  ' Miss. Gladys',
#  ' Miss. Anna',
#  ' Mrs. (Lutie Davis)',
#  ' Mr. Thomas',
#  ' Master. Edvin Rojj Felix',
#  ' Mr. Emil',
#  ' Mr. William',
#  ' Miss. Delia',
#  ' Mr. David',
#  ' Mr. Ernesti Arvid',
#  ' Mr. Ernst Ulrik',
#  ' Mrs. William Thompson (Edith Junkins)',
#  ' Miss. Amelia',
#  ' Mr. Alexander',
#  ' Mr. William Henry',
#  ' Mrs. (Elizabeth Anne Maidment)',
#  ' Mr. Charles H',
#  ' Miss. Hanora "Nora"',
#  ' Miss. Kornelia Theodosia',
#  ' Miss. Augusta Charlotta',
#  ' Mr. Francis "Frank"',
#  ' Master. Eric',
#  ' Mrs. Stanton (Rosa Hunt)',
#  ' Mr. Frank',
#  ' Mr. Nils Johan Goransson',
#  ' Mr. Alfons',
#  ' Mr. Edward Arthur',
#  ' Mr. Richard William',
#  ' Mr. Ivan',
#  ' Mr. Theodore',
#  ' Mr. Penko',
#  ' Mr. Masabumi',
#  ' Miss. Kate',
#  ' Miss. Ellen "Nellie"',
#  ' Mrs. Dickinson H (Helen Walton)',
#  ' Mr. Rene Jacques',
#  ' Miss. Aloisia',
#  ' Mr. Ivan',
#  ' Mr. Ervin G',
#  ' Mr. Mansour',
#  ' Miss. Helen Loraine',
#  ' Mr. Adolphe',
#  ' Mrs. James (Helene DeLaudeniere Chaput)',
#  ' Miss. Anna Katherine "Annie Kate"',
#  ' Mr. Bernard',
#  ' Mr. William Cahoone Jr',
#  ' Miss. Nora A',
#  ' Mr. Howard Hugh "Harry"',
#  ' Master. Hudson Trevor',
#  ' Miss. Margaret',
#  ' Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)',
#  ' Mr. Samuel',
#  ' Miss. Laura Mabel',
#  ' Miss. Margaret Bechstein',
#  ' Miss. Emily Borie',
#  ' Mrs. William (Anna Sylfven)',
#  ' Mr. Ignjac',
#  ' Mr. Benjamin',
#  ' Miss. Helmina Josefina',
#  ' Mrs. Sinai (Miriam Sternin)',
#  ' Dr. Ernest',
#  ' Miss. Mary Natalie',
#  ' Mrs. Frederic Oakley (Margaretta Corning Stone)',
#  ' Mr. Samuel',
#  ' Mr. Yoto',
#  ' Miss. Hilda Mary',
#  ' Mrs. Albert Francis (Sylvia Mae Harbaugh)',
#  ' Mr. George John Jr',
#  ' Miss. Marie Grice',
#  ' Mr. Johan Hansen',
#  ' Mrs. (Ada E Hall)',
#  ' Mrs. Frank John (Emily Alice Brown)',
#  ' Miss. Jean Gertrude',
#  ' Miss. Agnes',
#  ' Mr. Austen',
#  ' Mr. George Edward',
#  ' Mr. Leo Edmondus',
#  ' Mrs. Henry William (Clara Heinsheimer)',
#  ' Mr. Mitto',
#  ' Mr. Thomas Clinton',
#  ' Miss. Elizabeth Margaret',
#  ' Mr. Karl Edwart',
#  ' Mr. Stephen Weart',
#  ' Master. Edmond Roger',
#  ' Miss. Alice Elizabeth',
#  ' Mr. Erik Gustaf',
#  ' Mr. Charles Frederick Waddington',
#  ' Mr. Stanley Hubert',
#  ' Miss. Amelia "Mildred"',
#  ' Miss. Marion Elsie',
#  ' Mrs. Thomas Henry (Mary E Finck)',
#  ' Master. William Loch "William"',
#  ' Mr. Jovan',
#  ' Mr. Nils Martin',
#  ' Mr. Fletcher Fellows',
#  ' Mr. Tannous',
#  ' Mr. Josef',
#  ' Mr. Wazli',
#  ' Mr. Leo Peter',
#  ' Miss. Elsie Edith',
#  ' Miss. Annie Clemmer',
#  ' Miss. Mary',
#  ' Miss. Helen Mary "Ellie"',
#  ' Mr. Wilhelm',
#  ' Mr. Sebastiano',
#  ' Mrs. (Catherine David)',
#  ' Mr. Adola',
#  ' Mr. Thomas',
#  ' Mr. Mauritz Nils Martin',
#  ' Mrs. Frank Manley (Anna Sophia Atkinson)',
#  ' Mrs. (Mantoura Boulos)',
#  ' Miss. Annie',
#  ' Mme. Leontine Pauline',
#  ' Mr. George Achilles',
#  ' Mr. Jakob Alfred',
#  ' Mr. William Thomas',
#  ' Mr. Sante',
#  ' Miss. Stina Viola',
#  ' Mrs. Edgar Joseph (Leila Saks)',
#  ' Miss. Aurora Adelia',
#  ' Mr. Harry Elkins',
#  ' Mr. Tannous',
#  ' Mr. Karl Gideon',
#  ' Miss. Rosalie',
#  ' Miss. Maria ("Mary")',
#  ' Mr. Juho',
#  ' Mrs. Alexander Oskar (Mary Aline Towner)',
#  ' Mr. Vasil',
#  ' Mr. Charles Henry',
#  ' Master. Sidney Leonard',
#  ' Miss. Kate',
#  ' Mr. Matthew',
#  ' Miss. Bertha',
#  ' Mr. William Ernest',
#  ' Mr. Carl Olof',
#  ' Mr. Johan Birger',
#  ' Miss. Marjorie',
#  ' Mrs. Hjalmar (Agnes Charlotta Bengtsson)',
#  ' Mr. Erik',
#  ' Miss. Elina',
#  ' Mr. Peter David',
#  ' Dr. Alfred',
#  ' Mrs. William H (Jessie L)',
#  ' Mr. Juha',
#  ' Mr. John',
#  ' Miss. Mari Aina',
#  ' Mr. Pekka Pietari',
#  ' Miss. Marija',
#  ' Mr. Shadrach',
#  ' Mr. Carl/Charles Peter',
#  ' Master. William Rowe',
#  ' Mr. Hans Martin Monsen',
#  ' Miss. Ida',
#  ' Mr. Todor',
#  ' Mr. Henry',
#  ' Miss. Daisy E',
#  ' Mr. Alfred Fleming',
#  ' Mr. Johan Julian',
#  ' Mrs. Thomas (Annie Louise Rowley)',
#  ' Mrs. James Vivian (Lulu Thorne Christian)',
#  ' Miss. Lyyli Karoliina',
#  ' Mr. William John',
#  ' Miss. Catharina',
#  ' Mr. Stanio',
#  ' Mr. David',
#  ' Mr. Leo',
#  ' Mrs. Ernst Gilbert (Anna Sigrid Maria Brogren)',
#  ' Mr. Viktor Richard',
#  ' Mr. Phillippe',
#  ' Mrs. Charles V (Ada Maria Winfield)',
#  ' Miss. Kate Florence ("Mrs Kate Louise Phillips Marshall")',
#  ' Mr. James',
#  ' Mr. Berk (Berk Trembisky)',
#  ' Mr. Mauritz Hakan',
#  ' Mrs. Percival (Florence Kate White)',
#  ' Mrs. Charles Alexander (Alice Adelaide Slow)',
#  ' Mr. Nikolai Erland',
#  ' Mr. William Baird',
#  ' Miss. Lucile Polk',
#  ' Miss. Doolina Margaret "Daisy"',
#  ' Mrs. Sidney (Emily Hocking)',
#  ' Mr. Mark',
#  ' Mr. Johan Henrik Johannesson',
#  ' Mrs. Benjamin (Esther Ada Bloomfield)',
#  ' Mr. Leon',
#  ' Mr. Johan Emil',
#  ' Ms. Encarnacion',
#  ' Mr. Bernt',
#  ' Master. Washington',
#  ' Miss. Madeleine Violet',
#  ' Mr. Frederic Kimber',
#  ' Miss. Marie Catherine',
#  ' Major. Arthur Godfrey',
#  ' Mr. Edwy Arthur',
#  ' Mr. Ingvald Olai Olsen',
#  ' Mr. Benjamin Laventall',
#  ' Mr. Samuel L',
#  ' Mr. Joseph',
#  ' Mr. Ivan',
#  ' Mr. Francis Davis',
#  ' Mrs. Frederick R (Marion)',
#  ' Miss. Ellen',
#  ' Mr. Maurice',
#  ' Mr. Harry',
#  ' Mr. William',
#  ' Mr. Arthur H',
#  ' Mr. Jacob Christian',
#  ' Mr. Simon',
#  ' Mr. Manuel Estanslas',
#  ' Mr. William',
#  ' Mr. John Montgomery',
#  ' Mr. James',
#  ' Miss. Helene Barbara',
#  ' Mr. Arthur',
#  ' Mr. Luka',
#  ' Mrs. Edwy Arthur (Ada Mary Worth)',
#  ' Mrs. Amin S (Marie Marthe Thuillard)',
#  ' Miss. Ida Sofia',
#  ' Mr. George Quincy',
#  ' Mr. Peter Henry',
#  ' Mr. Lewis Richard',
#  ' Mr. Nils August',
#  ' Miss. Hildur E',
#  ' Master. Harold Victor',
#  ' Mr. Anthony Wood "Archie"',
#  ' Mr. Richard Henry',
#  ' Mrs. (Hedwig)',
#  ' Mr. Dickinson H',
#  ' Miss. Jeannie',
#  ' Mrs. Frederick Maxfield (Jane Anne Forby)',
#  ' Mr. Edward Austin',
#  ' Mr. Francis William',
#  ' Master. Eden Leslie "Neville"',
#  ' Mr. Konrad Mathias Reiersen',
#  ' Mr. Einar',
#  ' Mr. Harry Markland',
#  ' Mr. Ramon',
#  ' Mr. Edward Roland',
#  ' Mr. Gerious',
#  ' Miss. Elizabeth Mussey',
#  ' Mr. Frederick William',
#  ' Mrs. Hudson J C (Bessie Waldo Daniels)',
#  ' Mr. Olof',
#  ' Mr. Petar',
#  ' Miss. Mary',
#  ' Miss. Bridget Mary',
#  ' Miss. Kristina Sofia',
#  ' Miss. Roberta',
#  ' Mr. Victor de Satode',
#  ' Mrs. Frederick Charles (Jane Richards)',
#  ' Mr. George ("George Arthur Brayton")',
#  ' Mr. Henry Margido',
#  ' Mr. Fang',
#  ' Mr. Eugene Patrick',
#  ' Mr. James',
#  ' Mr. James Robert',
#  ' Mrs. Martin (Elizabeth L. Barrett)',
#  ' Mr. Satio',
#  ' Mr. William Anderson',
#  ' Mrs. (Amelia Milley)',
#  ' Mr. Patrick',
#  ' Mrs. William A (Florence "Mary" Agnes Hughes)',
#  ' Mr. Stefo',
#  ' Miss. Anne',
#  ' Mr. Janko',
#  ' Mr. Sarkis',
#  ' Mrs. Louis Albert (Ida Sophia Fischer)',
#  ' Mr. Fared',
#  ' Mr. James',
#  ' Miss. Lucy',
#  ' Mr. John',
#  ' Mr. Johan Werner',
#  ' Mr. Richard George',
#  ' Miss. Phyllis May',
#  ' Mr. Nakli',
#  ' Mr. Joseph Jr',
#  ' Mrs. Catherine (Catherine Rizk)',
#  ' Miss. Marija',
#  ' Miss. Eva Miriam',
#  ' Major. Archibald Willingham',
#  ' Miss. Bertha',
#  ' Mr. Samuel Beard',
#  ' Miss. Hedwig Margaritha',
#  ' Miss. Harriet R',
#  ' Miss. Ingeborg Constanzia',
#  ' Miss. Sigrid Elisabeth',
#  ' Mr. Edward',
#  ' Mr. Walter Donald',
#  ' Mr. Arthur Ernest',
#  ' Mrs. Edward (Ethel Clarke)',
#  ' Mr. Julian',
#  ' Mr. Frank John',
#  ' Master. John Morgan Jr',
#  ' Mr. John Borland Jr',
#  ' Mr. Percival James R',
#  ' Mr. Timothy',
#  ' Mr. Fahim ("Philip Zenni")',
#  ' Miss. Velin',
#  ' Mr. George',
#  ' Lady. (Lucille Christiana Sutherland) ("Mrs Morgan")',
#  ' Mr. Victor',
#  ' Mrs. Emil (Tillie Mandelbaum)',
#  ' Mrs. Guillaume Joseph (Emma)',
#  ' Mr. Thomas Rowan',
#  ' Mr. Husein',
#  ' Mr. Robert Douglas',
#  ' Mr. John',
#  ' Miss. (Marion Ogden)',
#  ' Mr. Alfred J',
#  ' Mr. Ilia',
#  ' Mrs. Nils (Alma Cornelia Berglund)',
#  ' Mr. Tannous',
#  ' Mr. Carl',
#  ' Mr. George',
#  ' Mrs. Edward Dale (Charlotte Lamson)',
#  ' Mr. John Irwin ("Irving")',
#  ' Miss. Mary',
#  ' Mr. Alfred George John',
#  ' Mr. George',
#  ' Miss. Ethel',
#  ' Mrs. William Baird (Alice Munger)',
#  ' Mrs. Joseph (Maria Elias)',
#  ' Mr. Eiriik',
#  ' Miss. Julie Rachel',
#  ' Mrs. John Borland (Marian Longstreth Morris)',
#  ' Mr. William James',
#  ' Mr. John Hugo',
#  ' Mr. Uscher',
#  ' Miss. Ruth',
#  ' Mr. John Denzil',
#  ' Mr. Maxmillian',
#  ' Mr. Eliezer',
#  ' Mr. Joseph',
#  ' Mr. Matti',
#  ' Mrs. Walter Bertram (Martha Eustis)',
#  ' Mr. William James',
#  ' Miss. Mary',
#  ' Mr. John Henry',
#  ' Mr. Jean Baptiste',
#  ' Miss. Jessie Wills',
#  ' Mr. Alfred',
#  ' Mr. Hanna',
#  ' Sir. Cosmo Edmund ("Mr Morgan")',
#  ' Mrs. Sidney Samuel (Amy Frances Christy)',
#  ' Mr. Petco',
#  ' Mr. Charles H',
#  ' Mr. Ernst William',
#  ' Mr. Harry ("Mr E Haven")',
#  ' Mr. Edvard Bengtsson',
#  ' Mr. Milan',
#  ' Mr. Robert Williams',
#  ' Mrs. Joseph (Juliette Marie Louise Lafargue)',
#  ' Miss. Elizabeth W',
#  ' Mrs. Anders Johan (Alfrida Konstantia Brogren)',
#  ' Mr. Jose Neto',
#  ' Miss. Margaret Jane',
#  ' Mr. John',
#  ' Mr. William Alfred',
#  ' Miss. Alice',
#  ' Mr. Ernst Gilbert',
#  ' Mrs. William Arthur (Cordelia K Stanlick)',
#  ' Miss. Marion Louise',
#  ' Mr. Lawrence',
#  ' Mr. Antoni',
#  ' Mr. Edwin Nelson Jr',
#  ' Mr. Sahid',
#  ' Mr. Henry Damsgaard',
#  ' Mr. David John "Dai"',
#  ' Mr. Frederick',
#  ' Rev. Charles Leonard',
#  ' Miss. Gretchen Fiske',
#  ' Mr. Guentcho',
#  ' Mr. Patrick D',
#  ' Mr. Algernon Henry Wilson',
#  ' Mr. Johan Svensson',
#  ' Dr. Max',
#  ' Mr. William Henry Marsh',
#  ' Miss. Mabel',
#  ' Miss. Mary',
#  ' Mr. Antti Gustaf',
#  ' Mr. Harvey',
#  ' Mrs. Juha (Maria Emilia Ojala)',
#  ' Mr. Percival',
#  ' Mr. Hans Peder',
#  ' Mlle. Emma',
#  ' Miss. Margit Elizabeth',
#  ' Mr. Choong',
#  ' Miss. Eugenie',
#  ' Mr. Henry Sleeper',
#  ' Mr. Liudevit',
#  ' Col. Oberst Alfons',
#  ' Mr. Edward',
#  ' Miss. Amy Zillah Elsie',
#  ' Mr. Mito',
#  ' Miss. Elsie',
#  ' Mr. Johannes Halvorsen',
#  ' Miss. Hanora "Norah"',
#  ' Miss. Hanora "Nora"',
#  ' Mr. Leonard Mark',
#  ' Mr. Alexander',
#  ' Mrs. John (Catherine)',
#  ' Mr. George Floyd',
#  ' Mr. Arthur Webster',
#  ' Dr. Henry William',
#  ' Mr. Mohamed',
#  ' Mr. Edward Pomeroy',
#  ' Mr. Peju',
#  ' Mr. Eino William',
#  ' Mr. Lewis',
#  ' Mr. Reginald Fenton',
#  ' Mr. Knud Paust',
#  ' Mr. Jacob',
#  ' Mrs. Elmer Zebley (Juliet Cummins Wright)',
#  ' Mrs. Thomas William Solomon (Elizabeth Catherine Ford)',
#  ' Mr. Thornton',
#  ' Mr. Henry Michael',
#  ' Mr. Charles',
#  ' Mr. Ennis Hastings',
#  ' Mr. Gustaf Hjalmar',
#  ' Mr. Frederick Charles',
#  ' Miss. Anna Sofia',
#  ' Mrs. Frederick (Augusta Tyler)',
#  ' Mr. Thomas Drake Martinez',
#  ' Miss. Katie',
#  ' Mr. Hammad',
#  ' Mr. Thor Anderson',
#  ' Mr. Charles Edward',
#  ' Mr. Thomas William Solomon',
#  ' Mr. Joseph Philippe Lemercier',
#  ' Mr. Jaako Arnold',
#  ' Mr. Branko',
#  ' Mr. Eberhard Thelander',
#  ' Miss. Georgette Alexandra',
#  ' Mr. Albert Adrian',
#  ' Miss. Manca',
#  ' Mr. Ali',
#  ' Mr. Khalil',
#  ' Col. John',
#  ' Mr. Charles Henry',
#  ' Mr. James',
#  ' Miss. Katherine "Katie"',
#  ' Mr. John Borland',
#  ' Mr. Adolf Mathias Nicolai Olsen',
#  ' Mrs. John Jacob (Madeleine Talmadge Force)',
#  ' Mr. Spencer Victor',
#  ' Miss. Saiide',
#  ' Mr. Martin',
#  ' Mr. Henrik Juul',
#  ' Mr. Henry Samuel ("Mr Henry Marshall")',
#  ' Mrs. Florence "Fannie"',
#  ' Mr. Edward Pennington',
#  ' Miss. Alice',
#  ' Master. Halim Gonios ("William George")',
#  ' Mlle. Berthe Antonine ("Mrs de Villiers")',
#  ' Mr. Herman',
#  ' Mr. Elmer Zebley',
#  ' Mr. August Viktor',
#  ' Mr. Samuel',
#  ' Mr. Peter Andreas Lauritz Andersen',
#  ' Miss. Caroline Louise',
#  ' Miss. Edwina Celia "Winnie"',
#  ' Mr. Michael',
#  ' Mr. Malkolm Joackim',
#  ' Miss. Annie Jessie "Nina"',
#  ' Mr. Svend Lauritz',
#  ' Mr. William Henry',
#  ' Mr. Henry Price',
#  ' Mr. Norman Campbell',
#  ' Mr. Luka',
#  ' Mrs. Peter Henry (Lillian Jefferys)',
#  ' Miss. Margareth',
#  ' Mr. Kurt Arnold Gottfrid',
#  ' Miss. Pieta Sofia',
#  ' Miss. Elisabeth Walton',
#  ' Mr. Houssein G N',
#  ' Mr. Robert J',
#  ' Mr. William John',
#  ' Mr. Moses Aaron',
#  ' Mr. Leslie',
#  ' Mrs. Edward (Margaret Ann Watson)',
#  ' Mr. Gustave J',
#  ' Mr. Kanio',
#  ' Mr. Minko',
#  ' Mr. Walter James',
#  ' Mr. Tyrell William',
#  ' Miss. Susan Parker "Suzette"',
#  ' Mr. Neal',
#  ' Mr. Juho',
#  ' Capt. Edward Gifford',
#  ' Mr. Rossmore Edward',
#  ' Miss. Anna',
#  ' Mr. Daniel Warner',
#  ' Mr. Michael',
#  ' Miss. Joan',
#  ' Master. Meier',
#  ' Mr. Johannes Joseph',
#  ' Mr. Lalio',
#  ' Mrs. Samuel (Jane Laver)',
#  ' Master. Viljo',
#  ' Mr. August Sigfrid',
#  ' Mr. Percy Andrew',
#  ' Mr. Thomas Leonard',
#  ' the Countess. of (Lucy Noel Martha Dyer-Edwards)',
#  ' Mr. John',
#  ' Mr. Iisakki Antino Aijo',
#  ' Mr. Hanna Assi',
#  ' Mrs. William Ernest (Lucile Polk)',
#  ' Mr. Hans Linus',
#  ' Mrs. John C (Anna Andrews)',
#  ' Dr. Arthur Jackson',
#  ' Miss. Mary',
#  ' Mr. Daniel J',
#  ' Mr. Daniel Danielsen',
#  ' Mr. Rene Aime',
#  ' Mr. Niels Peder',
#  ' Mrs. (Mary)',
#  ' Mr. Dibo',
#  ' Mrs. Elizabeth (Eliza Needs)',
#  ' Mr. Pehr Fabian Oliver Malkolm',
#  ' Mr. Roger',
#  ' Miss. Virginia Ethel',
#  ' Mr. Thomas J',
#  ' Mrs. Edward Scott (Elisabeth Walton McMillan)',
#  ' Miss. Banoura',
#  ' Mrs. Albert Adrian (Vera Gillespie)',
#  ' Mr. Milton Clyde',
#  ' Mr. Andrew G',
#  ' Mr. William',
#  ' Mr. Abraham (David Lishin)',
#  ' Miss. Anna Sofia',
#  ' Master. George Hugh',
#  ' Master. Bertram Vere',
#  ' Mr. Benjamin',
#  ' Mr. Andrew "Andy"',
#  ' Mr. Alfred',
#  ' Miss. Stella Anna',
#  ' Mr. William Fisher',
#  ' Mr. Ristiu',
#  ' Mr. Richard',
#  ' Dr. Alice (Farnham)',
#  ' Mrs. Mara',
#  ' Mr. Yousseff',
#  ' Mrs. Jean Baptiste (Rosalie Paula Govaert)',
#  ' Mr. Martin',
#  ' Mrs. Harvey (Charlotte Annie Tate)',
#  ' Master. William Thornton II',
#  ' Master. Assad Alexander',
#  ' Mr. Oskar Arvid',
#  ' Mr. Karl Johan',
#  ' Mr. Thomas Jr',
#  ' Miss. Ellen Natalia',
#  ' Mr. August',
#  ' Mrs. Norman Campbell (Bertha Griggs)',
#  ' Mr. William',
#  ' Mr. James',
#  ' Mr. Richard James',
#  ' Miss. Ebba Iris Alfrida',
#  ' Mr. Ernest Portage',
#  ' Mr. Richard',
#  ' Miss. Wendla Maria',
#  ' Mr. Albert',
#  ' Mr. John Fredrik Alexander',
#  ' Master. Karl Thorsten',
#  ' Mrs. Charles Melville (Clara Jennings Gregg)',
#  ' Mr. Nikola',
#  ' Jonkheer. John George',
#  ' Mrs. (Beila)',
#  ' Master. Urho Abraham',
#  ' Mr. John',
#  ' Mr. Len',
#  ' Master. Andre',
#  ' Mr. Thomas Joseph',
#  ' Mrs. George Nelson (Martha Evelyn)',
#  ' Mrs. Antoni (Selini Alexander)',
#  ' Master. George Sibley',
#  ' Mr. Amin',
#  ' Mr. Albert',
#  ' Mr. Owen George',
#  ' Miss. Sara Rebecca',
#  ' Mr. Jakob',
#  ' Mr. Maurice',
#  ' Mr. Chang',
#  ' Mr. Pierre',
#  ' Mr. Ilmari Rudolf',
#  ' Mr. Thomas Charles',
#  ' Miss. Augusta',
#  ' Mr. Peter L',
#  ' Mr. Jeso',
#  ' Mr. Anthony',
#  ' Mr. Douglas Bullen',
#  ' Mr. Marin',
#  ' Rev. John',
#  ' Mrs. Samuel L (Edwiga Grabowska)',
#  ' Master. Sigvard Harald Elias',
#  ' Mr. Johan',
#  ' Miss. Nourelain',
#  ' Miss. Mary Conover',
#  ' Mrs. Ernest Courtenay (Lilian Hughes)',
#  ' Mrs. Sam (Leah Rosen)',
#  ' Mrs. George Dennick (Mary Hitchcock)',
#  ' Mr. Peter Denis ',
#  ' Mrs. Solomon (Latifa Qurban)',
#  ' Mr. Raihed',
#  ' Mr. Claus Peter',
#  ' Mr. Frederick Edward',
#  ' Mrs. Frederick Joel (Margaret Welles Barron)',
#  ' Miss. Dorothy Edith "Dolly"',
#  ' Mr. John William',
#  ' Mrs. (Karolina)',
#  ' Miss. Asuncion',
#  ' Mr. Washington Augustus II',
#  ' Mr. Philemon',
#  ' Master. Harold Theodor',
#  ' Mr. Cerin',
#  ' Mrs. Richard Leonard (Sallie Monypeny)',
#  ' Mr. Frans Olof',
#  ' Mr. Victor',
#  ' Mrs. Samuel (Hannah Wizosky)',
#  ' Miss. Adele Kiamie "Jane"',
#  ' Mr. Alfred Ossian',
#  ' Mr. Nedelio',
#  ' Mr. Kristo',
#  ' Mrs. Thomas Jr (Lily Alexenia Wilson)',
#  ' Mrs. William (Imanita Parrish Hall)',
#  ' Mr. Johann',
#  ' Miss. Gerda Ulrika',
#  ' Mr. Frederick James',
#  ' Mr. Henry Jr',
#  ' Mrs. William (Margaret Norton)',
#  ' Rev. Juozas',
#  ' Miss. Margaret Edith',
#  ' Miss. Catherine Helen "Carrie"',
#  ' Mr. Karl Howell',
#  ' Mr. Patrick']

# %%
title = [i.split(",")[1].split(".")[0].strip() for i in df_titanic["Name"]]
df_titanic["Title"] = pd.Series(title)
df_titanic["Title"].head()
# Out:
# 0      Mr
# 1     Mrs
# 2    Miss
# 3     Mrs
# 4      Mr
# Name: Title, dtype: object

# %% [markdown]
# Title에 따른 생존율을 비교해보세요.

# %% [markdown]
# 너무 빈도가 적은 Title은 묶어도 되지 않을까?

# %% [markdown]
# Mr -> 1
# Miss -> 2
# Mrs -> 3
# Master, Dr -> 4
# Rev -> 5
# others -> 0

# %%
set([i.split(",")[1].split(".")[0] for i in df_titanic["Name"]])
# Out:
# {' Capt',
#  ' Col',
#  ' Don',
#  ' Dr',
#  ' Jonkheer',
#  ' Lady',
#  ' Major',
#  ' Master',
#  ' Miss',
#  ' Mlle',
#  ' Mme',
#  ' Mr',
#  ' Mrs',
#  ' Ms',
#  ' Rev',
#  ' Sir',
#  ' the Countess'}

# %%
[i.split(",")[1].split(".")[0] for i in df_titanic["Name"]]
# Out:
# [' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Don',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Rev',
#  ' Rev',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Master',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Rev',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Dr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mme',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Dr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Ms',
#  ' Mr',
#  ' Master',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Major',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Miss',
#  ' Major',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Lady',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Sir',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Rev',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mlle',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Col',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Col',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mlle',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Capt',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' the Countess',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Dr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Master',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Dr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Master',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mrs',
#  ' Mr',
#  ' Jonkheer',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Rev',
#  ' Mrs',
#  ' Master',
#  ' Mr',
#  ' Miss',
#  ' Miss',
#  ' Mrs',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Master',
#  ' Mr',
#  ' Mrs',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Mrs',
#  ' Mr',
#  ' Miss',
#  ' Mr',
#  ' Mr',
#  ' Mrs',
#  ' Rev',
#  ' Miss',
#  ' Miss',
#  ' Mr',
#  ' Mr']

# %% [markdown]
# 이와 같이, Ticket과 Cabin도 분석해보세요.

# %%
df_titanic['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df_titanic['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
for cabin in df_titanic['Cabin'][df_titanic['Cabin'].notnull()]:
    print(cabin)
# Out:
# C85
# C123
# E46
# G6
# C103
# D56
# A6
# C23 C25 C27
# B78
# D33
# B30
# C52
# B28
# C83
# F33
# F G73
# C23 C25 C27
# E31
# A5
# D10 D12
# D26
# C110
# B58 B60
# E101
# D26
# F E69
# D47
# C123
# B86
# F2
# C2
# E33
# B19
# A7
# C49
# F4
# A32
# F2
# B4
# B80
# G6
# A31
# D36
# D15
# C93
# C83
# C78
# D35
# G6
# C87
# B77
# E67
# B94
# C125
# C99
# C118
# D7
# A19
# B49
# D
# C22 C26
# C106
# B58 B60
# E101
# C22 C26
# C65
# E36
# C54
# B57 B59 B63 B66
# C7
# E34
# C32
# D
# B18
# C124
# C91
# C2
# E40
# T
# F2
# C23 C25 C27
# F33
# C128
# E33
# D37
# B35
# E50
# C82
# B96 B98
# D36
# G6
# C78
# E10
# C52
# E44
# B96 B98
# C23 C25 C27
# A34
# C104
# C111
# C92
# E38
# D21
# E12
# E63
# D
# A14
# B49
# C93
# B37
# C30
# D20
# C22 C26
# B79
# C65
# E25
# D46
# F33
# B73
# B18
# C95
# B38
# B39
# B22
# C86
# C70
# A16
# E67
# C101
# E25
# E44
# C68
# A10
# E68
# B41
# D20
# A20
# C125
# F4
# D19
# D50
# D9
# A23
# B50
# B35
# D33
# A26
# D48
# E58
# C126
# B71
# B51 B53 B55
# D49
# B5
# B20
# C68
# F G63
# C62 C64
# E24
# E24
# C90
# C124
# C126
# F G73
# C45
# E101
# E8
# B5
# B101
# D45
# C46
# B57 B59 B63 B66
# B22
# D30
# E121
# B77
# B96 B98
# D11
# E77
# F38
# B3
# B20
# D6
# B82 B84
# D17
# B96 B98
# A36
# E8
# B102
# B69
# E121
# B28
# E49
# C47
# C92
# D28
# E17
# D17
# A24
# D35
# B51 B53 B55
# C50
# B42
# C148

# %%
cabin_num = [cabin.split()[0][0] for cabin in df_titanic['Cabin'][df_titanic['Cabin'].notnull()]]
df_titanic["CabinCode"] = pd.Series(cabin_num)
sns.set(font_scale=2) # 폰트 크기 키우기
sns.catplot(x="CabinCode", col="SibSp",  data=df_titanic,
                 height=7,  kind="count", palette="muted")
